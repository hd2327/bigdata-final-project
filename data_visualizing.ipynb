# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=60)

D = {u'BROOKLYN  ':402084, u'QUEENS': 341431, u'MANHATTAN':293064, u'BRONX': 185555, u'STATEN ISLAND':53787}

plt.bar(range(len(D)), list(D.values()), align='center')
plt.xticks(range(len(D)), list(D.keys()))
# # for python 2.x:
# plt.bar(range(len(D)), D.values(), align='center')  # python 2.x
# plt.xticks(range(len(D)), D.keys())  # in python 2.x
plt.title("NYC Motor Vehicle Collisions of Each Borough")
plt.show()

# %%
D = {u'SUV':547100,
     u'SEDAN': 470765, u'LIVERY VEHICLE':293064,
     u'TAXI': 76773, u'TRUCK':64086,
     u'4 DR SEDAN': 42096, u'VAN':32683,
     u'BUS': 31344, u'OTHER':22126,
     u'LARGE COM VEH': 15143}
figure(figsize=(10, 6), dpi=60)
plt.bar(range(len(D)), list(D.values()), align='center')
plt.xticks(range(len(D)), list(D.keys()))
# # for python 2.x:
# plt.bar(range(len(D)), D.values(), align='center')  # python 2.x
# plt.xticks(range(len(D)), D.keys())  # in python 2.x
plt.title("Top 10 Vihecle Types in NYC Moter Vihecle Collisions")
plt.show()

# %%
D = {u'UNSPECIFIED': 645920,
     u'DRIVER INATTENTION/DISTRACTION': 354755, 
     u'FAILURE TO YIELD RIGHT-OF-WAY': 106466,
     u'FOLLOWING TOO CLOSELY': 96194, 
     u'BACKING UNSAFELY': 69547,
     u'OTHER VEHICULAR': 56683, 
     u'PASSING OR LANE USAGE IMPROPER': 47611,
     u'TURNING IMPROPERLY': 43821, 
     u'PASSING TOO CLOSELY': 43506,
     u'FATIGUED/DROWSY': 42407}
figure(figsize=(40, 6), dpi=60)
plt.bar(range(len(D)), list(D.values()), align='center')
plt.xticks(range(len(D)), list(D.keys()))
# # for python 2.x:
# plt.bar(range(len(D)), D.values(), align='center')  # python 2.x
# plt.xticks(range(len(D)), D.keys())  # in python 2.x
plt.title("Top 10 Collision Factors in NYC Moter Vihecle Collisions")
plt.show()

# %%
D = { '02:00 - 06:00': 88971,
     '06:00 - 10:00': 290844,
     '10:00 - 14:00': 394945,
     '14:00 - 18:00': 500474,
     '18:00 - 22:00': 348612,
     '22:00 - 02:00': 193152}
figure(figsize=(10, 6), dpi=60)
myList = D.items()
myList = sorted(myList) 
x, y = zip(*myList) 
plt.plot(x, y)
plt.title("Top 10 Collision Time Range in NYC Moter Vihecle Collisions")
plt.show()
